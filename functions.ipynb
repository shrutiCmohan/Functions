# %% [markdown]
# #theory questions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#      - Function
#            - It is block of code which is called by its name.
#            - The function may or may not have different parameters.
#            - It may or may not return any data.
#            - Functions are independent blocks of code that can be called from anywhere.
#            - eg.
#            def factorial(n):
#                  return 1 if (n==1 or n==0) else n * factorial(n-1);
#      - Method
#            - Method is called by its name, but it is associated to an object.
#            - methods are tied to objects or classes.
#            - methods offer behavior specific to objects.
#            - methods are accessed using dot notation.
#            - eg.
#            class Addition:
#                 def add(self, num1, num2):
#                     return num1 + num2
#                 print(Addition.add)
#
# 2.  Explain the concept of function arguments and parameters in Python.
#      - A parameter is the variable defined in the a function when we declare it.
#      - An argument is a value that is passed to a function when it is called. It might be a variable or value passed to a function as input.
#      - eg.
#      def sum(a,b):
#         print (a+b)   here a,b are parameters
#
#
#         sum(1,2)      here 1,2 are arguments
#
# 3. What are the different ways to define and call a function in Python?
#     - In programming, a function is a reusable block of code that executes a certain functionality when it is called. you define a function with the def keyword, then write the function identifier (name) followed by parentheses and a colon. To callfunction, write the name of the function followed by parentheses.
#   eg.
#   def myfunction():
#       print("Hello World")
#   myfunction()
#     - Arguments in Python Functions = you can pass arguments into the function.
#      eg. def functionName(arg1, arg2)
#     - Return Keyword in Python = you can use the return keyword to exit a function so it goes back to where it was called.
#      eg.
#      def multiplyNum(num1):
#         return num1 * 2
#
#      result = multiplyNum(8)
#      print(result)                output= 16
#
# 4. What is the purpose of the `return` statement in a Python function?
#     - The python return statement is used to return values from the function.
#     - We can use the return statement in a function only. It can't be used outside of a Python function.
#     -  If the function doesn't have any return statement, then it returns None.
#     - eg.
#         def add(x, y):
#            result = x + y
#            return result
#        output = add(5, 4)
#        print(f'Output of add(5, 4) function is {output}')
#
# 5. What are iterators in Python and how do they differ from iterables?
#     - Iteration is a process of using a loop to access all the elements of a sequence. Iterator is used to iterate over the sequence. In Python, both the terms iterators and iterables are sometimes used interchangeably but they have different meanings. Iterable is an object which can be iterated upon, and an iterator is an object which keeps a state and produces the next value each time it is iterated upon. Every iterator is an iterable, but not every iterable is an iterator.  an iterator implements the iterator protocol, which consist of the methods __iter__() and __next__().
#     eg.
#       tuple = ("apple", "banana", "cherry")
#       t = iter(tuple)
#
#       print(next(t))      #output apple
#       print(next(t))      #output banana
#
# 6.  Explain the concept of generators in Python and how they are defined.
#       - Python Generators return the statement and make iterator pbject.
#       - Generators are useful when we want to produce a large sequence of values, but we don't want to store all of them in memory at once.
#       - a generator function defined using yield keyword.
#       def generator_name(arg):
#           #statements
#       yield something
#       - the yield keyword is used to produce a value from the generator.
#       eg.
#       def square(n):
#         for i in range(n):
#         yield i**2
#      gen= square(10)
#
#      next(gen)   #output 0
#      next(gen)   #output 1
#      next(gen)   #output 4
#      till 9
#
# 7. What are the advantages of using generators over regular functions?
#     - Generators are Easy to Implement.
#     - Generator implementation of sequences is memory friendly and is preferred as it only produces one item at a time.
#     - Generators are excellent mediums to represent an infinite stream of data.
#
# 8. What is a lambda function in Python and when is it typically used?
#      - Lambda functions are similar to user-defined functions but without a name. They're commonly referred to as anonymous functions. When user want only simple expressions that are usually a single line of a statement lambda used here. for example if you want square of number then normally we code as =
#      def f(x):
#       return x ** 2
#   but using lambda =
#   x= lambda x:x**2
#
# 9.  Explain the purpose and usage of the map() function in Python.
#      - Map function used to execute a specified function for each of item of an iterables. When you need to apply a transformation function to each item in an iterable and turn it into a new iterable, you can use the map() function.
#      - syntax: map(function, *iterables)
#      - example
#       def Cube(n):
#          return n*n*n
#
#       num = (1, 2, 3, 4, 5)
#       result = map(Cube, num)
#       print(result)
#
# 10. What is the difference between map(), reduce(), and filter() functions in Python?
#      - Map function used to execute a specified function for each of item of an iterables. When you need to apply a transformation function to each item in an iterable and turn it into a new iterable, you can use the map() function.
#      example
#      s='sneha'
#      list(map(lambda x x.upper(),s))
#      - reduce function applies a given function to the elements of an iterable, reducing them to a single value.
#      example
#      l= [2,1,5,7,8]
#      reduce(lambda x,y:x+y,l)
#      - The filter function can be applied to an iterable such as a list or a dictionary and create a new iterator.  This new iterator can filter out certain specific elements based on the condition that you provide.
#      example
#      num=[1,9,5,4,6,8]
#      odd = filter(lambda p : p%2 != 0, nums)
#      print("The list of odd numbers is: ", list(odd))

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#    ![photo_2025-01-21_16-17-17.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #PRACTICAL QUESTIONS

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list

def even_sum(a):
  sum=0
  for i in a:
    if i%2==0:
      sum=sum+i
  return sum
even_sum([1,2,3,4,5,6,7,10])
# Out:
# 22

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.
def reverse(a):
  return a[::-1]
reverse("namaste")
# Out:
# 'etsaman'

# %%
#3. . Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square(a):
  b=[]
  for i in a:
    b.append(i**2)
  return b
square([1,2,3,4,5])
# Out:
# [1, 4, 9, 16, 25]

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
a = 0
b = 1
n=int(input("Enter the number of terms in the sequence: "))
print(a,b,end=" ")
while(n-2):
    c=a+b
    a,b = b,c
    print(c,end=" ")
    n=n-1
# Out:
# Enter the number of terms in the sequence: 4
# 0 1 1 2

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def power_generator(exponent, base=2):
    result = 1
    for i in range(exponent + 1):
        yield result
        result = result* base
exponent = int(input("Input the exponent of 2: "))
for power in power_generator(exponent,base=2):
    print(power)
# Out:
# Input the exponent of 2: 4
# 1
# 2
# 4
# 8
# 16

# %%
#8.  Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
x=[('Shruti',57), ('Rahul', 43), ('neha', 60), ('vijay', 24)]
sorted(x,key=lambda x:x[1])
# Out:
# [('vijay', 24), ('Rahul', 43), ('Shruti', 57), ('neha', 60)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
places = [('Nashik',32),("nagpur",35),("pune",40), ("mumbai",29)]

flist = list(map(lambda c: (c[0],  (9/5) * c[1]+ 32), places))
print(flist)
# Out:
# [('Nashik', 89.6), ('nagpur', 95.0), ('pune', 104.0), ('mumbai', 84.2)]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
